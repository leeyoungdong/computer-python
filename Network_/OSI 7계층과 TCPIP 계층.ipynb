# %% [markdown]
# # **OSI 7계층과 TCP/IP 계층**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# (네트워크 인터페이스 계층: TCP/IP 5계층에서 물리계층과 링크계층을 하나로 묶은것)

# %% [markdown]
# OSI 7계층은 TCP/IP계층의 애플리케이션 계층을 더 세분화 한 것이다. TCP/IP계층과 다른 응용계층, 표현계층, 세션계층으로 응용계층이 세분화 된다.

# %% [markdown]
# **응용 계층(Application Layer)**
#
# 사용자 혹은 애플리케이션이 네트워크에 접근할 숭 있도록 해주는 계층이다. 사용자를 위한 인터페이스를 지원하며, 사용자에게 보이는 유일한 계층이다. 메일전송, 인터넷 접속 등의 작업을 수행할 수있다.

# %% [markdown]
# **표현 계층(Presentation Layer)**
#
# 응용계층으로부터 전달받거나 전송하는 데이터의 인코딩 및 디코딩이 이뤄지는 계층이다. 응용 계층에서 데이터를 이해할 수 있도록, 응용프로그램에 맞춰 변환하게됨. 예를드러 jpeg, tiff, gif등의 다양한 포맷을 구분

# %% [markdown]
# **세션 계층(Session Layer)**
#
# 응용프로세스가 통신을 관리하기 위한 방법을 정의. 네트워크상 양쪽 연결을 관리/지속시키는 역할과 세션을 만들거나 없애는 역할을 담당하는 계층이다. 통신하는 사용자들을 동기화 하고 오류 복구를 진행. 통신연결은 포트를 기반으로 구성하여 연결되며, os가 세션계층에 속함함
