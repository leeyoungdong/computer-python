# %% [markdown]
# # **DNS란?**

# %% [markdown]
# 네트워크 통신에는 고유의 주소인 IP주소가 필요. 통신을 주고받는 주체가 되는 네트워크에 연결되어 있는 모든 장치들을 HOST라고 함. IP는 사람이 이해하고 기억하기 어렵기 때문에 이를 위해 각 IP에 부여한 이름이 도메인(DOMAIN)이다.
#
# DNS(Domin Name Server or Domain Name Service)는 숫자로 이뤄진 IP주소와 일정한 형식을 가진 도메인을 서로 매핑 시키고 정보를 갖고 있음.
#
#  주소창에 도메인을 입력하면, 컴퓨터는 해당 도메인이 연결된 DNS로 가서 서버 IP를 요청 > 요청받은 네임 서버는 해당 도메인과 연결되어있는 서버를 찾은 후, 컴퓨터에게 알려줌.
#
#  도메인에 연결된 서버의 주소를 찾아주는 역할이 DNS이다.

# %% [markdown]
# **브라우저가 도메인에 해당하는 IP를 찾는 순서**
#
# 1. Local cache 안에 검색한 해당 도메인의 IP가 있는지 확인함. 이미 해당 도메인을 방문한 적이 있다면 컴퓨터가 해당 도메인의  IP를 기억하고 있으므로, 그것을 사용
# 2. 만약 캐시에 없다면 컴퓨터 내부에 파일 형태로 존재하는 HOSTS파일을 검색해 찾고, 해당 파일에 특정 도메인과 IP를 매핑시켜놓으면 해당 도메인은 지정한 IP로 이동
# 3. 만약 위 경우에서 도메인에 대한 IP를 찾지 못하면 최종적으로 DNS를 검색색

# %% [markdown]
# ![image.png](data:image/png;base64,...)
